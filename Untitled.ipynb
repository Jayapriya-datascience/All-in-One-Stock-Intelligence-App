# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Download Apple stock data
data = yf.download('AAPL', start='2015-01-01', end='2023-01-01', timeout=30)

# Display first few rows
data.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-01-02  24.288580  24.757334  23.848706  24.746226  212818400
# 2015-01-05  23.604330  24.137511  23.417718  24.057533  257142000
# 2015-01-06  23.606556  23.866481  23.244437  23.668760  263188400
# 2015-01-07  23.937565  24.037535  23.704298  23.815377  160423600
# 2015-01-08  24.857311  24.915073  24.148625  24.266371  237458000

# %%
plt.figure(figsize=(14,6))
plt.plot(data['Close'], label='Closing Price')
plt.title('Apple Stock Price (2015–2023)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
close_prices = data[['Close']]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(close_prices)

# %%
X = []
y = []
sequence_length = 60

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i, 0])
    y.append(scaled_data[i, 0])

X = np.array(X)
y = np.array(y)

# %%
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
train_size = int(len(X) * 0.8)
X_train = X[:train_size]
y_train = y[:train_size]
X_test = X[train_size:]
y_test = y[train_size:]

# %%
model = Sequential()

# 1st LSTM layer
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))

# 2nd LSTM layer
model.add(LSTM(units=50))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=1))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# View model summary
model.summary()
# Out:
# D:\Apps\app anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,651 (119.73 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - loss: 0.0167 - val_loss: 0.0050
# Epoch 2/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 3/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 4/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 8.9419e-04 - val_loss: 0.0025
# Epoch 5/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 7.4094e-04 - val_loss: 0.0018
# Epoch 6/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 7/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 9.1277e-04 - val_loss: 0.0023
# Epoch 8/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 8.4478e-04 - val_loss: 0.0014
# Epoch 9/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 8.0177e-04 - val_loss: 0.0023
# Epoch 10/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 7.0913e-04 - val_loss: 0.0013
# Epoch 11/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 9.2526e-04 - val_loss: 0.0013
# Epoch 12/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 7.9729e-04 - val_loss: 0.0067
# Epoch 13/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 8.5099e-04 - val_loss: 0.0012
# Epoch 14/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 8.1418e-04 - val_loss: 0.0013
# Epoch 15/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 6.6387e-04 - val_loss: 0.0015
# Epoch 16/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 7.2891e-04 - val_loss: 0.0024
# Epoch 17/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 7.1323e-04 - val_loss: 0.0041
# Epoch 18/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 7.3568e-04 - val_loss: 0.0017
# Epoch 19/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 6.3508e-04 - val_loss: 0.0038
# Epoch 20/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 7.1592e-04 - val_loss: 0.0011

# %%
# Predict on test set
predicted_prices = model.predict(X_test)

# Undo scaling
predicted_prices = scaler.inverse_transform(predicted_prices)
actual_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step

# %%
plt.figure(figsize=(14,6))
plt.plot(actual_prices, color='blue', label='Actual Price')
plt.plot(predicted_prices, color='red', label='Predicted Price')
plt.title('Stock Price Prediction (Test Set)')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(actual_prices, predicted_prices)
mae = mean_absolute_error(actual_prices, predicted_prices)

print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Squared Error: 26.44870847163712
# Mean Absolute Error: 4.0893526394348925

# %%
import warnings
warnings.filterwarnings('ignore')
model.save("lstm_stock_price_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Save the LSTM model
model.save('lstm_stock_model.h5')

# Save the scaler
import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler.pkl']

# %%
# !pip install --upgrade yfinance
# Out:
# Requirement already satisfied: yfinance in d:\apps\app anaconda\lib\site-packages (0.2.61)
# Requirement already satisfied: pandas>=1.3.0 in d:\apps\app anaconda\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in d:\apps\app anaconda\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in d:\apps\app anaconda\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\apps\app anaconda\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\apps\app anaconda\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in d:\apps\app anaconda\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in d:\apps\app anaconda\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in d:\apps\app anaconda\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\apps\app anaconda\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in d:\apps\app anaconda\lib\site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in d:\apps\app anaconda\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in d:\apps\app anaconda\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in d:\apps\app anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in d:\apps\app anaconda\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in d:\apps\app anaconda\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\apps\app anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\apps\app anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\apps\app anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\apps\app anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\apps\app anaconda\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in d:\apps\app anaconda\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in d:\apps\app anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
import requests
import pandas as pd
from io import StringIO

url = "https://query1.finance.yahoo.com/v7/finance/download/AAPL?period1=1420070400&period2=1672531200&interval=1d&events=history&includeAdjustedClose=true"
headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
data = pd.read_csv(StringIO(response.text))
print(data.head())
# Out:
# Empty DataFrame
# Columns: [{"finance":{"result":null, error:{"code":"unauthorized", description:"User is not logged in"}}}]
# Index: []
